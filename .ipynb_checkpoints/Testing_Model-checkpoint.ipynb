# %%
from model import HotspotPredictor
import pandas as pd
import numpy as np
import mysql.connector as msc
import datetime as dt
from collections import Counter
from bokeh.io import output_file, show, output_notebook
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)
from sklearn.cluster import KMeans
import random
from sklearn.ensemble import RandomForestRegressor
from geopy.distance import vincenty
from sklearn.cross_validation import train_test_split, cross_val_score
# Out:
# /Users/William/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
engine = msc.connect(user='root', password='asdfghjkl;',
                              host='127.0.0.1',
                              database='rideaustin')
df = pd.read_sql(
    'SELECT start_location_lat,start_location_long, created_date,tod, status, total_fare \
    FROM rides  \
    WHERE status = "NO_AVAILABLE_DRIVER" \
    OR status = "Completed";', engine)

# %%
hotspot = HotspotPredictor(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-a82ba64e72ec> in <module>()
# ----> 1 hotspot = HotspotPredictor(df)
#
# /Users/William/Desktop/RideAustin_Capstone/model.py in __init__(self, df)
#      40         self.df = self.df[(self.df['start_location_long'] >=-97.819014) & (self.df['start_location_long'] <= -97.647192)]
#      41         #Create timeblock column
# ---> 42         self.df['period'] = self.df.apply(self.period, axis=1)
#      43
#      44
#
# /Users/William/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4150                     if reduce is None:
#    4151                         reduce = True
# -> 4152                     return self._apply_standard(f, axis, reduce=reduce)
#    4153             else:
#    4154                 return self._apply_broadcast(f, axis)
#
# /Users/William/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4220             res_index = self.index
#    4221             res_columns = self.columns
# -> 4222             values = self.values
#    4223             series_gen = (Series.from_array(arr, index=res_columns, name=name,
#    4224                                             dtype=dtype)
#
# /Users/William/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in values(self)
#    2924         will result in a flot64 dtype.
#    2925         """
# -> 2926         return self.as_matrix()
#    2927
#    2928     @property
#
# /Users/William/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in as_matrix(self, columns)
#    2905         self._consolidate_inplace()
#    2906         if self._AXIS_REVERSED:
# -> 2907             return self._data.as_matrix(columns).T
#    2908         return self._data.as_matrix(columns)
#    2909
#
# /Users/William/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in as_matrix(self, items)
#    3401             return mgr.blocks[0].get_values()
#    3402         else:
# -> 3403             return mgr._interleave()
#    3404
#    3405     def _interleave(self):
#
# /Users/William/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in _interleave(self)
#    3428         for blk in self.blocks:
#    3429             rl = blk.mgr_locs
# -> 3430             result[rl.indexer] = blk.get_values(dtype)
#    3431             itemmask[rl.indexer] = 1
#    3432
#
# /Users/William/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get_values(self, dtype)
#    1669         if is_object_dtype(dtype):
#    1670             return lib.map_infer(self.values.ravel(),
# -> 1671                                  self._box_func).reshape(self.values.shape)
#    1672         return self.values
#    1673
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:66124)()
#
# /Users/William/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in <lambda>(x)
#    1681     @property
#    1682     def _box_func(self):
# -> 1683         return lambda x: tslib.Timedelta(x, unit='ns')
#    1684
#    1685     def fillna(self, value, **kwargs):
#
# KeyboardInterrupt:

# %%
errors = hotspot.create_random_tests(df=df,n_repititions=10)
# Out:
# model.py:305: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# 321561  NO_AVAILABLE_DRIVER         NaN      43
# 321562  NO_AVAILABLE_DRIVER         NaN      43
# 321563  NO_AVAILABLE_DRIVER         NaN      43
# 321564  NO_AVAILABLE_DRIVER         NaN      43
# 321565  NO_AVAILABLE_DRIVER         NaN      43
# 321566            COMPLETED        6.12      43
# 321567  NO_AVAILABLE_DRIVER         NaN      43
# 321568  NO_AVAILABLE_DRIVER         NaN      43
# 321569  NO_AVAILABLE_DRIVER         NaN      43
# 321570  NO_AVAILABLE_DRIVER         NaN      43
# 321571            COMPLETED       31.70      43
# 321572  NO_AVAILABLE_DRIVER         NaN      43
# 321573  NO_AVAILABLE_DRIVER         NaN      43
# 321574  NO_AVAILABLE_DRIVER         NaN      43
# 321575  NO_AVAILABLE_DRIVER         NaN      43
# 321576  NO_AVAILABLE_DRIVER         NaN      43
# 321577  NO_AVAILABLE_DRIVER         NaN      43
# 321578  NO_AVAILABLE_DRIVER         NaN      43
# 321579  NO_AVAILABLE_DRIVER         NaN      43
# 321580  NO_AVAILABLE_DRIVER         NaN      43
# 321581  NO_AVAILABLE_DRIVER         NaN      43
# 321582            COMPLETED       15.00      43
# 321583            COMPLETED        9.20      43
# 321584  NO_AVAILABLE_DRIVER         NaN      43
# 321585  NO_AVAILABLE_DRIVER         NaN      43
#
# [18681 rows x 7 columns]

# %%
d1,d2 = hotspot.split_at_date(df,pd.to_datetime('2016-10-09 22:00:00'))
cents, cent_dict = hotspot.create_centroids(d1)

# %%
previous_hotspots = pd.DataFrame(cents[:,0], columns=['lat'])
previous_hotspots['long']= cents[:,1]
d11 = d1[d1['total_fare']!=0.00]
previous_hotspots['avg_fare'] = d11.groupby(['cluster'])['total_fare'].mean()
previous_hotspots['percent_fulfilled'] = d1.groupby(['cluster'])['status_value'].mean()

# %%
previous_hotspots['requests'] = d1.groupby(['cluster'])['start_location_lat'].count()

# %%
previous_hotspots.to_csv('previous_hotspots.csv')

# %%
model = KMeans(n_clusters=5)
model.fit(np.array(d2[['start_location_lat','start_location_long']]))
centroident = model.cluster_centers_
d2['cluster'] = model.labels_
# Out:
# /Users/William/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plot_Austin_centroids(cents,num_datapoints= len(d1),centroid_dictionary=cent_dict, unfulfilled_rides=d1)

# %%
d1['period'] = d1.apply(hotspot.period,axis=1)
# Out:
# /Users/William/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
d1 = d1[d1['period']>=42]

# %%
b_loon = {'COMPLETED':1,'NO_DRIVER_AVAILABLE':0}
d1['status_value'] = d1['status'].map(b_loon)
# Out:
# /Users/William/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
d1['cluster'].unique()
# Out:
# array([0, 2, 3, 4, 1])

# %%
# Out:
# cluster
# 0    12.439747
# 1    20.069167
# 2    12.284731
# 3    13.031343
# 4    16.499231
# Name: total_fare, dtype: float64

# %%
# Out:
# cluster
# 0    745
# 1     93
# 2    184
# 3    358
# 4    126
# Name: start_location_lat, dtype: int64

# %%
d1 = d1.fillna(value=0)

# %%
dd = pd.DataFrame(d1.groupby(['cluster'])['status_value'].mean())

# %%
dd['total_rides'] = d1.groupby(['cluster'])['start_location_lat'].count()
dd['avg_fare'] = d1.groupby(['cluster'], as_index=True)['total_fare'].mean()

# %%
dd['lat'] =
# Out:
#          status_value  total_rides  avg_fare
# cluster
# 0            0.318121          745  3.957342
# 1            0.129032           93  2.589570
# 2            0.505435          184  6.209130
# 3            0.603352          358  7.862486
# 4            0.309524          126  5.106905

# %%
def plot_Austin_centroids(centroids, centroid_dictionary,num_datapoints, completed_rides=None, unfulfilled_rides=None):
    '''
    Takes in centroid values from create_centroids() and centroid_dictionary and plots the centroids relative to their
    intensity. Optional inputs for the lat-long columns for completed_rides (green) and unfulfilled_rides(blue).
    
    INPUT:
    - centroids (numpy array)
    - centroid_dict (dictionary)
    - copmleted_rides (dataframe)
    - unfulfilled_rides (dataframe)
    
    OUTPUT:
    -None
    '''
    #creating the plot
    map_options = GMapOptions(lat=30.29, lng=-97.73, map_type="roadmap", zoom=11)

    plot = GMapPlot(
        x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options
    )
    plot.title.text = "Austin"
    plot.api_key = "AIzaSyBx-cLXm4jxpg0aX_nnUnwd2hir3Ve0j9w"
    
    #create alpha based on intensity
    alpha = []
    for key, value in centroid_dictionary.iteritems():
        al_value = value[2]/float(num_datapoints)
        al_fixed = al_value+.25
        alpha.insert(key,al_fixed)
    
    #try if completed_rides is populated
    try:
        completed_lats = list(completed_rides['start_location_lat'])
        completed_longs = list(completed_rides['start_location_long'])
        completed_source = ColumnDataSource( data=dict(
            lat=completed_lats,
            lon=completed_longs,
    )
)
        completed_dots = Circle(x="lon", y="lat", size=15, fill_color="green", fill_alpha=0.1, line_color=None)
        plot.add_glyph(completed_source, completed_dots)
    except:
        pass
    
    #try if unfulfilled_rides is populated
    try:
        unfulfilled_lats = list(unfulfilled_rides['start_location_lat'])
        unfulfilled_longs = list(unfulfilled_rides['start_location_long'])
        unfulfilled_source = ColumnDataSource(
        data=dict(
            lat=unfulfilled_lats,
            lon=unfulfilled_longs,

        )
    )
        unfulfilled_dots = Circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
        plot.add_glyph(unfulfilled_source, unfulfilled_dots)
    except:
        pass
    #creating centroid source and circle
    centroidlats = centroids[:,0]
    centroidlongs = centroids[:,1]
    centroid_source = ColumnDataSource(
        data=dict(
            lat=centroidlats, 
            lon=centroidlongs,
             alpha=alpha
        )
    )
    centroid_dots = Circle(x="lon", y="lat", size=45, fill_color='#8B008B', fill_alpha='alpha', line_color=None)
    plot.add_glyph(centroid_source, centroid_dots)
    
    #finishing the plot
    plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
    show(plot)

# %%
dd['lat']= cents[:,0]
dd["long"] = cents[:,1]

# %%
dd.to_csv('current_hotspots.csv')

# %%
neighborhoods = {'nSoco':[[30.256315, -97.745302],[30.243497, -97.753048]],
                'sSoco':[[30.239975, -97.750773],[30.227151, -97.762931]],
                'nSoLamar': [[30.262691, -97.755906],[30.251125, -97.766893]],
                'midSoLamar': [[30.250847, -97.765198],[30.245926, -97.777751]],
                'sSoLamar':[[30.245926, -97.777751],[30.234609, -97.795969]],
                'Downtown':[[30.283521,-97.730909],[30.261218, -97.762784]],
                'Guadeloupe':[[30.297992, -97.740339],[30.281659, -97.743150]],
                'Domain':[[30.406832, -97.715588],[30.393294, -97.730930]],
                'Airport':[[30.215680, -97.659969],[30.199964,-97.674904]]}

# %%
for i in neighborhoods:
    print neighborhoods[i][0][0]
# Out:
# 30.261218
# 30.406832
# 30.281659
# 30.245926
# 30.256315
# 30.250847
# 30.239975
# 30.262691
# 30.21568

# %%
def neighborhood(row):
    nbhd = 'None'
    for area in neighborhoods:
        lat = row['start_location_lat']
        lon = row['start_location_long']
        if lat <= neighborhoods[area][0][0] and lat >= neighborhoods[area][1][0]\
         and lon <= neighborhoods[area][0][1] and lon >= neighborhoods[area][1][1]:
            nbhd = area
    return nbhd

# %%
neighborhoods['Downtown'][0][1]
# Out:
# -97.730909

# %%
for x in d1.loc[:,'start_location_lat']:
    if x <= neighborhoods['Downtown'][0][0] and x >= neighborhoods['Downtown'][0][1]:
        print x
# Out:
# 30.268438
# 30.214381
# 30.271621
# 30.23698
# 30.281789
# 30.235719
# 30.274565
# 30.2332
# 30.246493
# 30.251277
# 30.281789
# 30.24056
# 30.1813927587
# 30.246493
# 30.282725
# 30.274565
# 30.199004
# 30.255466
# 30.235216
# 30.264752
# 30.274565
# 30.228511
# 30.227585
# 30.282725
# 30.227264
# 30.282725
# 30.2077181442
# 30.274565
# 30.209257
# 30.235087
# 30.247345
# 30.247345
# 30.245261
# 30.282725
# 30.264882
# 30.247345
# 30.247345
# 30.247345
# 30.247345
# 30.197429
# 30.247345
# 30.237755
# 30.247345
# 30.210107
# 30.26022
# 30.247345
# 30.223204
# 30.247345
# 30.210107
# 30.247345
# 30.235649
# 30.282374
# 30.210014
# 30.247345
# 30.260505
# 30.260568
# 30.229004
# 30.267775
# 30.268501
# 30.247345
# 30.247345
# 30.244566
# 30.235649
# 30.267983
# 30.258413
# 30.235649
# 30.260829
# 30.266616
# 30.282374
# 30.210014
# 30.247345
# 30.247345
# 30.264524
# 30.235442
# 30.282534
# 30.2021489
# 30.264527
# 30.267492
# 30.265339
# 30.264737
# 30.262063
# 30.235442
# 30.25613
# 30.266616
# 30.269084
# 30.210047
# 30.267101
# 30.268771
# 30.235442
# 30.246493
# 30.269084
# 30.1974292
# 30.280847
# 30.235266
# 30.235266
# 30.258035
# 30.247047
# 30.235266
# 30.269084
# 30.235266
# 30.235442
# 30.269084
# 30.260488
# 30.235266
# 30.269491
# 30.269084
# 30.267967
# 30.235266
# 30.269491
# 30.235266
# 30.277164
# 30.235266
# 30.203382
# 30.277164
# 30.2494374
# 30.235442
# 30.269062
# 30.253087
# 30.276295
# 30.26486
# 30.202745
# 30.251624
# 30.269084
# 30.237525
# 30.235266
# 30.253347
# 30.203437
# 30.237525
# 30.235442
# 30.235266
# 30.262277
# 30.26945
# 30.269084
# 30.268982
# 30.235442
# 30.278858
# 30.253087
# 30.276271
# 30.237668
# 30.235266
# 30.077229
# 30.276271
# 30.242674
# 30.235442
# 30.276271
# 30.235442
# 30.2529
# 30.235266
# 30.265104
# 30.237485
# 30.221221
# 30.077229
# 30.235266
# 30.256593
# 30.270508
# 30.235442
# 30.235266
# 30.237485
# 30.266574
# 30.22797
# 30.256769
# 30.245552
# 30.275354
# 30.218404
# 30.235266
# 30.283303
# 30.276271
# 30.269218
# 30.237583
# 30.276271
# 30.235266
# 30.235442
# 30.281704
# 30.270508
# 30.077229
# 30.283034
# 30.248003
# 30.237583
# 30.2522272704
# 30.229908
# 30.26718
# 30.235266
# 30.235442
# 30.158763
# 30.2523086527
# 30.235266
# 30.280024
# 30.235442
# 30.280667
# 30.235266
# 30.267775
# 30.248832
# 30.272106
# 30.269359
# 30.2341042726
# 30.267775
# 30.266616
# 30.202945
# 30.235266
# 30.237476
# 30.235442
# 30.2598129
# 30.259813
# 30.235266
# 30.197429
# 30.236954
# 30.237476
# 30.235266
# 30.237198
# 30.235266
# 30.253454
# 30.237476
# 30.237476
# 30.26414
# 30.203389
# 30.201715
# 30.237476
# 30.264444
# 30.253867
# 30.197429
# 30.242548
# 30.247029
# 30.265603
# 30.232162
# 30.237476
# 30.242945
# 30.252257
# 30.251238
# 30.235077
# 30.246327
# 30.266551
# 30.237476
# 30.2332
# 30.280933
# 30.241026
# 30.237476
# 30.269173
# 30.257257
# 30.2740746943
# 30.252023
# 30.23494
# 30.280539
# 30.237476
# 30.155463
# 30.272974
# 30.280744
# 30.237476
# 30.251957
# 30.237476
# 30.280744
# 30.238288
# 30.281987
# 30.274516
# 30.281987
# 30.280662
# 30.234291
# 30.281987
# 30.281012
# 30.280644
# 30.26432
# 30.237476
# 30.281987
# 30.247365
# 30.281987
# 30.280644
# 30.147342
# 30.237594
# 30.228476
# 30.281987
# 30.22926
# 30.188684
# 30.230698
# 30.268888
# 30.2614546093
# 30.214553
# 30.237654
# 30.281987
# 30.266616
# 30.280648
# 30.237276
# 30.248418
# 30.261658
# 30.267972
# 30.231436
# 30.263521
# 30.237276
# 30.2594101
# 30.232717
# 30.242739
# 30.274219
# 30.282604
# 30.236548
# 30.262136
# 30.2694249513
# 30.24411
# 30.277385
# 30.2445634
# 30.26679
# 30.257522
# 30.25702
# 30.280499
# 30.226468
# 30.2352508
# 30.248455
# 30.240763
# 30.268245
# 30.260687
# 30.267497
# 30.256613
# 30.260467
# 30.268705
# 30.233125
# 30.23889
# 30.233125
# 30.253887
# 30.256613
# 30.267555
# 30.268705
# 30.2794998882
# 30.207763
# 30.233125
# 30.197429
# 30.253887
# 30.26242
# 30.247723
# 30.261161
# 30.267839
# 30.282948
# 30.252592
# 30.282948
# 30.251107
# 30.199944
# 30.2523746853
# 30.2653104198
# 30.266275
# 30.28291
# 30.233125
# 30.214547557
# 30.238982
# 30.242984
# 30.276099
# 30.269117
# 30.269359
# 30.21025
# 30.255133
# 30.208139
# 30.266648
# 30.265248
# 30.209195
# 30.2793463
# 30.24056
# 30.267413
# 30.18344
# 30.267413
# 30.255245
# 30.2646603144
# 30.240009
# 30.147134
# 30.197429
# 30.2646603144
# 30.223613
# 30.231911
# 30.266644
# 30.256624
# 30.274696
# 30.239205
# 30.255245
# 30.255245
# 30.256624
# 30.266452
# 30.257046
# 30.255245
# 30.2164759
# 30.255245
# 30.223613
# 30.203032
# 30.245116
# 30.261509
# 30.242157
# 30.20928
# 30.2442
# 30.265688
# 30.264378
# 30.256891
# 30.256952
# 30.276559
# 30.226536
# 30.271591
# 30.256952
# 30.039252
# 30.2359449
# 30.209663
# 30.219583
# 30.257416
# 30.259912
# 30.271591
# 30.280068
# 30.27722
# 30.247434
# 30.274477
# 30.251437
# 30.276562
# 30.269554
# 30.251437
# 30.20284
# 30.269554
# 30.276562
# 30.280068
# 30.269284
# 30.271591
# 30.272132
# 30.269554
# 30.251437
# 30.26535
# 30.248179
# 30.271591
# 30.213524
# 30.280068
# 30.2771262399
# 30.269554
# 30.233286
# 30.251437
# 30.282184
# 30.2333149179
# 30.247434
# 30.280068
# 30.270508
# 30.251437
# 30.271591
# 30.269554
# 30.255018
# 30.280068
# 30.251437
# 30.268
# 30.280068
# 30.271591
# 30.241851
# 30.269554
# 30.251437
# 30.280068
# 30.202838
# 30.0875616
# 30.251437
# 30.269554
# 30.255018
# 30.26982
# 30.1974292
# 30.251437
# 30.282184
# 30.269554
# 30.248073
# 30.280068
# 30.26982
# 30.251437
# 30.269554
# 30.280068
# 30.255018
# 30.251437
# 30.26919
# 30.26982
# 30.269554
# 30.251458
# 30.251458
# 30.260188
# 30.248073
# 30.279418
# 30.280032
# 30.251458
# 30.242016
# 30.282323
# 30.260758
# 30.251458
# 30.26982
# 30.260222
# 30.282109
# 30.248047
# 30.264871
# 30.278531
# 30.249282
# 30.269704
# 30.2671906335
# 30.26982
# 30.282267
# 30.209663
# 30.263918
# 30.280079
# 30.280068
# 30.251468
# 30.282109
# 30.199432
# 30.251468
# 30.282109
# 30.209663
# 30.269554
# 30.251468
# 30.277212
# 30.282256
# 30.264904
# 30.251468
# 30.282109
# 30.269554
# 30.251468
# 30.237601
# 30.269554
# 30.251468
# 30.282256
# 30.282201
# 30.270863
# 30.251468
# 30.282159
# 30.269554
# 30.202298
# 30.251468
# 30.269554
# 30.260188
# 30.227818
# 30.251468
# 30.269554
# 30.26982
# 30.282159
# 30.259993
# 30.251468
# 30.282252
# 30.282256
# 30.2356160501
# 30.25941
# 30.264594
# 30.282159
# 30.255017
# 30.227995
# 30.227818
# 30.251468
# 30.282256
# 30.26439
# 30.255017
# 30.28225
# 30.281028
# 30.227995
# 30.251468
# 30.255017
# 30.282271
# 30.264299
# 30.282159
# 30.251468
# 30.282179
# 30.265212
# 30.251468
# 30.282159
# 30.259071
# 30.251468
# 30.210796
# 30.283326
# 30.251468
# 30.282179
# 30.255017
# 30.227871
# 30.202815
# 30.2261388865
# 30.251468
# 30.28218
# 30.258088
# 30.27515
# 30.228876
# 30.244274
# 30.251494
# 30.2155242249
# 30.27054
# 30.233802
# 30.282254
# 30.247631
# 30.233802
# 30.194313
# 30.228223
# 30.232913
# 30.252111
# 30.2602842
# 30.283326
# 30.23665
# 30.2540228785
# 30.228223
# 30.250435
# 30.252111
# 30.268982
# 30.229848
# 30.279827
# 30.252111
# 30.248821
# 30.280362
# 30.228223
# 30.222138
# 30.258909
# 30.279827
# 30.280362
# 30.244274
# 30.252111
# 30.228223
# 30.279827
# 30.234299
# 30.279827
# 30.269232
# 30.260188
# 30.279401
# 30.280362
# 30.244274
# 30.279827
# 30.249032
# 30.280362
# 30.204096
# 30.228223
# 30.259418
# 30.244274
# 30.279827
# 30.2655658
# 30.279827
# 30.260188
# 30.252111
# 30.190199
# 30.227993
# 30.190199
# 30.27438
# 30.269232
# 30.2754625
# 30.266551
# 30.256415
# 30.266551
# 30.220365
# 30.2342629
# 30.228075
# 30.2426984138
# 30.202825
# 30.266551
# 30.254147
# 30.266551
# 30.266551
# 30.218882
# 30.2261388865
# 30.244253
# 30.202744
# 30.226367
# 30.272208
# 30.269073
# 30.202326
# 30.251881
# 30.282063
# 30.1974292
# 30.2349921
# 30.258452
# 30.241572
# 30.267303
# 30.257123
# 30.237982
# 30.267303
# 30.200599
# 30.245709
# 30.267303
# 30.249437
# 30.267303
# 30.267303
# 30.267303
# 30.282807
# 30.260666
# 30.266962
# 30.241482
# 30.262563
# 30.251683
# 30.27016
# 30.275317
# 30.27016
# 30.269454
# 30.22904
# 30.269454
# 30.240193
# 30.253815
# 30.26532
# 30.215639
# 30.275317
# 30.245073
# 30.270067
# 30.270051
# 30.270067
# 30.237694
# 30.1974292
# 30.270067
# 30.270067
# 30.2145527721
# 30.269454
# 30.280188
# 30.208289
# 30.230842
# 30.237684
# 30.2174196
# 30.277402
# 30.269084
# 30.25435
# 30.25435
# 30.283238
# 30.25435
# 30.275317
# 30.271398
# 30.271398
# 30.254662
# 30.262648
# 30.267722
# 30.213016
# 30.253956
# 30.270059
# 30.265626
# 30.254681
# 30.252953
# 30.262118
# 30.231309
# 30.252953
# 30.262118
# 30.258763
# 30.249623
# 30.262118
# 30.252146
# 30.248209
# 30.275828
# 30.252953
# 30.25917
# 30.262118
# 30.249446
# 30.251012
# 30.2718954986
# 30.261703
# 30.252261
# 30.273613
# 30.262118
# 30.264643
# 30.2276719
# 30.271372
# 30.252953
# 30.256028
# 30.268982
# 30.210796
# 30.275118
# 30.268982
# 30.242365
# 30.242365
# 30.269772
# 30.243635
# 30.259505
# 30.242365
# 30.275433
# 30.249216
# 30.263814
# 30.266558
# 30.2496962761
# 30.259157
# 30.266092
# 30.268982
# 30.242365
# 30.269976
# 30.252261
# 30.2563113
# 30.26546
# 30.271926
# 30.2572051
# 30.253245
# 30.242365
# 30.26546
# 30.223681
# 30.271926
# 30.242911
# 30.242365
# 30.202744
# 30.259509
# 30.242365
# 30.234391
# 30.263311
# 30.250744
# 30.252159
# 30.245136
# 30.242352
# 30.242365
# 30.242352
# 30.242352
# 30.2434807417
# 30.242352
# 30.242352
# 30.242352
# 30.242352
# 30.2392286958
# 30.223204
# 30.252261
# 30.272028
# 30.261405379
# 30.2702993
# 30.256289
# 30.2349921
# 30.282967
# 30.249609
# 30.243833
# 30.242352
# 30.282967
# 30.2205792
# 30.235305
# 30.2205792
# 30.282967
# 30.2205792
# 30.282967
# 30.237115
# 30.282967
# 30.2697287057
# 30.2352507
# 30.237115
# 30.2352507
# 30.282967
# 30.275234
# 30.237115
# 30.23682

# %%
d1['area'] = d1.apply(neighborhood,axis=1)

# %%
dr = d1[d1['area']!='None']

# %%
fare = dr[['total_fare','area']]

# %%
fare = fare[fare['total_fare']!= 0.0]

# %%
drr['avg_fare'] = fare.groupby(['area'])['total_fare'].mean().values

# %%
drr.to_csv('current_areas.csv')

# %%
drr = pd.DataFrame(dr.groupby(['area'], as_index=False)['status_value'].mean())

# %%
drr['total_rides'] = (dr.groupby(['area'],as_index=False)['start_location_lat'].count() )['start_location_lat']

# %%
drr['avg_fare'] = (dr.groupby(['area'],as_index=False)['total_fare'].mean())['total_fare']

# %%
def match_lat_longs(row):
    for area in neighborhoods:
         if row['area'] == area:
            return neighborhoods[area]

# %%
drr['area_coordinates']=drr.apply(match_lat_longs,axis=1)

# %%
drr
# Out:
#          area  status_value  total_rides   avg_fare  \
# 0     Airport      1.000000           15  21.761333
# 1      Domain      0.800000           10  17.403750
# 2    Downtown      0.493776          241  11.896549
# 3  Guadeloupe      0.226667           75  13.516429
# 4  midSoLamar      1.000000            5   8.334000
# 5    nSoLamar      0.281250           32  19.110000
# 6       nSoco      0.666667           33  11.276818
# 7    sSoLamar      0.208333           48   9.271000
# 8       sSoco      0.571429           21  10.881667
#
#                                     area_coordinates
# 0  [[30.21568, -97.659969], [30.199964, -97.674904]]
# 1  [[30.406832, -97.715588], [30.393294, -97.73093]]
# 2  [[30.283521, -97.730909], [30.261218, -97.7627...
# 3  [[30.297992, -97.740339], [30.281659, -97.74315]]
# 4  [[30.250847, -97.765198], [30.245926, -97.7777...
# 5  [[30.262691, -97.755906], [30.251125, -97.7668...
# 6  [[30.256315, -97.745302], [30.243497, -97.7530...
# 7  [[30.245926, -97.777751], [30.234609, -97.7959...
# 8  [[30.239975, -97.750773], [30.227151, -97.7629...

# %%
drr.to_csv('current_areas.csv')

# %%
future_hotspots = pd.DataFrame(cents, columns=[['lat','long']])

# %%
future_hotspots.to_csv('future_hotspots.csv')

# %%
cents
# Out:
# array([[ 30.27791298, -97.74584305],
#        [ 30.23335194, -97.75710345],
#        [ 30.31067603, -97.71648712],
#        [ 30.39049817, -97.73950843],
#        [ 30.31676449, -97.84064379]])

# %%
areadf = df.copy()
areadf['area'] = areadf.apply(neighborhood,axis=1)

# %%
areadf
# Out:
#          start_location_lat  start_location_long        created_date      tod  \
# 0                 38.676306          -121.038976 2016-06-03 21:14:40 21:14:40
# 1                 38.676837          -121.037948 2016-06-03 22:11:31 22:11:31
# 2                 30.324098           -97.728592 2016-06-04 03:23:12 03:23:12
# 3                 30.316335           -97.732381 2016-06-04 03:31:04 03:31:04
# 4                 30.280125           -97.770152 2016-06-04 03:40:23 03:40:23
# 5                 30.271075           -97.725108 2016-06-04 03:55:27 03:55:27
# 6                 30.271075           -97.725108 2016-06-04 03:55:57 03:55:57
# 7                 30.269378           -97.746428 2016-06-04 04:11:10 04:11:10
# 8                 30.240889           -97.722964 2016-06-04 04:11:24 04:11:24
# 9                 30.269860           -97.746534 2016-06-04 04:16:17 04:16:17
# 10                30.208308           -97.775127 2016-06-04 04:16:18 04:16:18
# 11                30.264948           -97.744243 2016-06-04 04:16:42 04:16:42
# 12                30.292688           -97.744241 2016-06-04 04:34:44 04:34:44
# 13                30.292688           -97.744241 2016-06-04 04:35:00 04:35:00
# 14                30.208468           -97.775008 2016-06-04 05:05:28 05:05:28
# 15                30.208468           -97.775008 2016-06-04 05:06:16 05:06:16
# 1        NO_AVAILABLE_DRIVER         NaN        None
# 2        NO_AVAILABLE_DRIVER         NaN        None
# 3        NO_AVAILABLE_DRIVER         NaN        None
# 4        NO_AVAILABLE_DRIVER         NaN        None
# 5        NO_AVAILABLE_DRIVER         NaN        None
# 6        NO_AVAILABLE_DRIVER         NaN        None
# 7        NO_AVAILABLE_DRIVER         NaN    Downtown
# 8        NO_AVAILABLE_DRIVER         NaN        None
# 9        NO_AVAILABLE_DRIVER         NaN    Downtown
# 10       NO_AVAILABLE_DRIVER         NaN        None
# 11       NO_AVAILABLE_DRIVER         NaN    Downtown
# 12       NO_AVAILABLE_DRIVER         NaN        None
# 13       NO_AVAILABLE_DRIVER         NaN        None
# 14       NO_AVAILABLE_DRIVER         NaN        None
# 15       NO_AVAILABLE_DRIVER         NaN        None
# 16       NO_AVAILABLE_DRIVER         NaN        None
# 17       NO_AVAILABLE_DRIVER         NaN        None
# 18       NO_AVAILABLE_DRIVER         NaN        None
# 19       NO_AVAILABLE_DRIVER         NaN        None
# 20       NO_AVAILABLE_DRIVER         NaN        None
# 21       NO_AVAILABLE_DRIVER         NaN        None
# 22       NO_AVAILABLE_DRIVER         NaN        None
# 23       NO_AVAILABLE_DRIVER         NaN        None
# 24       NO_AVAILABLE_DRIVER         NaN    Downtown
# 25       NO_AVAILABLE_DRIVER         NaN    Downtown
# 26       NO_AVAILABLE_DRIVER         NaN        None
# 27       NO_AVAILABLE_DRIVER         NaN        None
# 28       NO_AVAILABLE_DRIVER         NaN        None
# 29       NO_AVAILABLE_DRIVER         NaN        None
# ...                      ...         ...         ...
# 1778638            COMPLETED       12.16        None
# 1778639            COMPLETED       20.48    Downtown
# 1778640            COMPLETED        6.06    Downtown
# 1778641            COMPLETED        6.06    Downtown
# 1778642            COMPLETED        8.31    Downtown
# 1778643            COMPLETED       11.88        None
# 1778644            COMPLETED        6.06        None
# 1778645            COMPLETED        8.89        None
# 1778646            COMPLETED        8.82    Downtown
# 1778647  NO_AVAILABLE_DRIVER         NaN        None
# 1778648  NO_AVAILABLE_DRIVER         NaN    Downtown
# 1778649  NO_AVAILABLE_DRIVER         NaN        None
# 1778650  NO_AVAILABLE_DRIVER         NaN        None
# 1778651  NO_AVAILABLE_DRIVER         NaN    Downtown
# 1778652  NO_AVAILABLE_DRIVER         NaN        None
# 1778653            COMPLETED        6.06        None
# 1778654            COMPLETED        7.94        None
# 1778655  NO_AVAILABLE_DRIVER         NaN        None
# 1778656            COMPLETED        7.09        None
# 1778657            COMPLETED        6.06    Downtown
# 1778658            COMPLETED        6.77        None
# 1778659            COMPLETED        6.32    Downtown
# 1778660            COMPLETED        6.26  Guadeloupe
# 1778661            COMPLETED        6.06    Downtown
# 1778662            COMPLETED        9.02    Downtown
# 1778663            COMPLETED        2.06        None
# 1778664  NO_AVAILABLE_DRIVER         NaN        None
# 1778665  NO_AVAILABLE_DRIVER         NaN  Guadeloupe
# 1778666  NO_AVAILABLE_DRIVER         NaN        None
# 1778667  NO_AVAILABLE_DRIVER         NaN        None
#
# [1778668 rows x 7 columns]

# %%
def prep_df(dataframe):
        '''
        takes in dataframe of raw data and cleans it so that it can be passed
        into my regression model to predict n_rides for the next half-hour block.

        input:
        -dataframe

        output:
        -X dataframe
        -y dataframe
        '''
        data = dataframe.copy()
        data['month']= data['created_date'].dt.month
        data['day'] = data['created_date'].dt.day
        data['day_of_week'] = data['created_date'].dt.weekday
        # creating a COUNT response variable
        data = data.groupby(['day_of_week','month','period','day','area'])['start_location_lat'].count().reset_index(name="count")
        #data = pd.get_dummies(data, columns=['day_of_week'], drop_first = True)
        y = data.pop('count')
        data.pop('area')
        X = data
        return X,y

# %%
areadf['period'] = areadf.apply(hotspot.period,axis=1)

# %%
# areadf = areadf[areadf.loc[:,'area']!='None']
areadf['area'].unique()
# Out:
# array(['Downtown', 'Domain', 'nSoco', 'nSoLamar', 'Airport', 'Guadeloupe',
#        'sSoLamar', 'midSoLamar', 'sSoco'], dtype=object)

# %%
airportdf = areadf[areadf.loc[:,'area']=='Airport']
Guadaloupe = areadf[areadf.loc[:,'area']=='Guadeloupe']
sSoLamar = areadf[areadf.loc[:,'area']=='sSoLamar']
midSoLamar = areadf[areadf.loc[:,'area']=='midSoLamar']
nSoLamar = areadf[areadf.loc[:,'area']=='nSoLamar']
nSoco = areadf[areadf.loc[:,'area']=='nSoco']
sSoco = areadf[areadf.loc[:,'area']=='sSoco']
Domain = areadf[areadf.loc[:,'area']=='Domain']
Downtown = areadf[areadf.loc[:,'area']=='Downtown']

# %%
dataframes = {'airportdf':airportdf,'Guadaloupe':Guadaloupe,
              'sSoLamar':sSoLamar,'midSoLamar':midSoLamar,'nSoLamar':nSoLamar,'nSoco':nSoco,'sSoco':sSoco,
              'Domain':Domain,'Downtown':Downtown}

# %%
date = pd.to_datetime('2016-10-09 22:00:00')

# %%
from sklearn.linear_model import LinearRegression
mod = LinearRegression()

# %%
X,y = hotspot.split_at_date(Domain,date)
X_train,y_train = prep_df(X)
X_test, y_test = prep_df(y)
std = np.var(y_train)**.5

# %%
mod.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# X_test = pd.get_dummies(columns=['day_of_week','month','period','day'],data=X_test)
low_estimate = mod.predict(X_test)-std
high_estimate = mod.predict(X_test)+std
print int(round(low_estimate)),int(round(high_estimate))
# Out:
# 1 5

# %%
dictionary = {}
for x in dataframes:
    Xd,yd = hotspot.split_at_date(dataframes[x],date)
    before_train,after_train = prep_df(Xd)
    print x,len(before_train)
    before_test, after_test = prep_df(yd)
    mod.fit(before_train,after_train)
    prediction = mod.predict(before_test)
    dictionary[str(x)] = prediction
# Out:
# Downtown 4747
# Domain 1309
# sSoLamar 1372
# nSoco 2211
# Guadaloupe 1926
# midSoLamar 713
# sSoco 1202
# nSoLamar 1957
# airportdf 2165

# %%
lst = []
for score in dictionary:
    Xd,yd = hotspot.split_at_date(dataframes[score],date)
    before_train,after_train = prep_df(Xd)
    y_previous = int(after_train.tail(1))
    print y_previous
    if dictionary[score] > y_previous:
        lst.append((score,1))
    else:
        lst.append((score,0))
# Out:
# 2
# 2
# 6
# 21
# 3
# 2
# 2
# 14
# 4

# %%
d2.groupby(['cluster'])['start_location_long'].count()
# Out:
# cluster
# 0     63
# 1      1
# 2      7
# 3    300
# 4     40
# Name: start_location_long, dtype: int64
